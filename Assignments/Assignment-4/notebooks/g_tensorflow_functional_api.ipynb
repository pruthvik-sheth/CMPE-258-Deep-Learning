# %% [markdown]
# # 3-Layer Neural Network for Non-linear Regression (TensorFlow Functional API)
#
# This notebook implements a 3-layer neural network using TensorFlow's Functional API. The Functional API provides more flexibility than the Sequential API while still maintaining a high level of abstraction. We'll also use TensorFlow's built-in training and evaluation features.
#
# We'll continue to use the same 3-variable non-linear function for our synthetic dataset to maintain consistency across implementations.

# %%
# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import time

# Set random seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Define the function to generate synthetic data
def true_function(X):
    """
    Non-linear function with 3 variables
    X should be a matrix with 3 columns
    """
    return 2 * tf.math.sin(X[:, 0]) + 3 * tf.math.cos(X[:, 1]) + 0.5 * X[:, 2]**2 + 0.1 * X[:, 0] * X[:, 1] * X[:, 2]

# Generate synthetic dataset
def generate_data(n_samples=1000):
    # Generate random inputs
    X = tf.cast(tf.random.uniform((n_samples, 3), -2, 2), tf.float32)

    # Calculate true output values
    y_true = true_function(X)

    # Add some noise
    y = y_true + tf.random.normal((n_samples,), 0, 0.5)

    return X, tf.reshape(y, (-1, 1))

# Generate training data
X_train, y_train = generate_data(1000)

# Generate test data
X_test, y_test = generate_data(200)

print(f"Training data shape: X = {X_train.shape}, y = {y_train.shape}")
print(f"Test data shape: X = {X_test.shape}, y = {y_test.shape}")
# Out:
# Training data shape: X = (1000, 3), y = (1000, 1)
# Test data shape: X = (200, 3), y = (200, 1)

# %% [markdown]
# ## Neural Network Implementation with TensorFlow Functional API
#
# Now we'll implement our 3-layer neural network using TensorFlow's Functional API. This approach allows for more flexible model architectures while still leveraging TensorFlow's high-level features for training and evaluation.

# %%
# Create model using Functional API
def create_functional_model(input_size, hidden1_size, hidden2_size, output_size):
    # Define input layer
    inputs = tf.keras.Input(shape=(input_size,))

    # First hidden layer with ReLU activation
    x = tf.keras.layers.Dense(
        hidden1_size,
        activation='relu',
        kernel_initializer=tf.keras.initializers.HeNormal()
    )(inputs)

    # Second hidden layer with ReLU activation
    x = tf.keras.layers.Dense(
        hidden2_size,
        activation='relu',
        kernel_initializer=tf.keras.initializers.HeNormal()
    )(x)

    # Output layer (no activation for regression)
    outputs = tf.keras.layers.Dense(
        output_size,
        activation=None,
        kernel_initializer=tf.keras.initializers.HeNormal()
    )(x)

    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="NonlinearRegression")

    return model

# Create model instance
input_size = 3
hidden1_size = 10
hidden2_size = 5
output_size = 1

model = create_functional_model(input_size, hidden1_size, hidden2_size, output_size)
model.summary()

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.005),
    loss='mse',  # Mean Squared Error
    metrics=['mae']  # Mean Absolute Error as additional metric
)

# Create TensorFlow dataset
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=1000).batch(64)

# Create validation dataset
val_dataset = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(64)

# Define callbacks for monitoring training
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=50,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=20,
        min_lr=0.0001
    )
]

# Train the model
start_time = time.time()
history = model.fit(
    train_dataset,
    epochs=3000,
    validation_data=val_dataset,
    callbacks=callbacks,
    verbose=1
)
end_time = time.time()
print(f"Training completed in {end_time - start_time:.2f} seconds")
# Out:
# Model: "NonlinearRegression"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 3)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 10)                  │              40 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │              55 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 10.8184 - mae: 2.7733 - val_loss: 9.2398 - val_mae: 2.5093 - learning_rate: 0.0050
# Epoch 2/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9436 - mae: 2.3365 - val_loss: 7.7951 - val_mae: 2.2996 - learning_rate: 0.0050
# Epoch 3/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6809 - mae: 2.1347 - val_loss: 6.1407 - val_mae: 2.0623 - learning_rate: 0.0050
# Epoch 4/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9725 - mae: 1.8364 - val_loss: 4.4441 - val_mae: 1.7788 - learning_rate: 0.0050
# Epoch 5/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7309 - mae: 1.5967 - val_loss: 3.5149 - val_mae: 1.5940 - learning_rate: 0.0050
# Epoch 6/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1931 - mae: 1.4751 - val_loss: 3.0838 - val_mae: 1.4926 - learning_rate: 0.0050
# Epoch 7/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7450 - mae: 1.3522 - val_loss: 2.7942 - val_mae: 1.4242 - learning_rate: 0.0050
# Epoch 8/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4826 - mae: 1.2810 - val_loss: 2.5759 - val_mae: 1.3625 - learning_rate: 0.0050
# Epoch 9/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1549 - mae: 1.2032 - val_loss: 2.3897 - val_mae: 1.3061 - learning_rate: 0.0050
# Epoch 10/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1363 - mae: 1.1925 - val_loss: 2.2042 - val_mae: 1.2486 - learning_rate: 0.0050
# Epoch 11/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9278 - mae: 1.1353 - val_loss: 2.0333 - val_mae: 1.1963 - learning_rate: 0.0050
# Epoch 12/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8322 - mae: 1.1036 - val_loss: 1.8630 - val_mae: 1.1406 - learning_rate: 0.0050
# Epoch 13/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6031 - mae: 1.0204 - val_loss: 1.7019 - val_mae: 1.0819 - learning_rate: 0.0050
# Epoch 14/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5256 - mae: 0.9749 - val_loss: 1.5337 - val_mae: 1.0155 - learning_rate: 0.0050
# Epoch 15/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3797 - mae: 0.9290 - val_loss: 1.3775 - val_mae: 0.9555 - learning_rate: 0.0050
# Epoch 16/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2336 - mae: 0.8760 - val_loss: 1.2241 - val_mae: 0.8858 - learning_rate: 0.0050
# Epoch 17/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0078 - mae: 0.7931 - val_loss: 1.0824 - val_mae: 0.8238 - learning_rate: 0.0050
# Epoch 18/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9299 - mae: 0.7587 - val_loss: 0.9392 - val_mae: 0.7472 - learning_rate: 0.0050
# Epoch 19/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7875 - mae: 0.6996 - val_loss: 0.8078 - val_mae: 0.6904 - learning_rate: 0.0050
# Epoch 20/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7345 - mae: 0.6704 - val_loss: 0.7093 - val_mae: 0.6488 - learning_rate: 0.0050
# Epoch 21/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6168 - mae: 0.6257 - val_loss: 0.6356 - val_mae: 0.6286 - learning_rate: 0.0050
# Epoch 22/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6112 - mae: 0.6319 - val_loss: 0.5736 - val_mae: 0.5963 - learning_rate: 0.0050
# Epoch 23/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5776 - mae: 0.6104 - val_loss: 0.5412 - val_mae: 0.5799 - learning_rate: 0.0050
# Epoch 24/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5520 - mae: 0.5897 - val_loss: 0.5136 - val_mae: 0.5615 - learning_rate: 0.0050
# Epoch 25/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4878 - mae: 0.5617 - val_loss: 0.5001 - val_mae: 0.5508 - learning_rate: 0.0050
# Epoch 26/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5047 - mae: 0.5664 - val_loss: 0.4919 - val_mae: 0.5454 - learning_rate: 0.0050
# Epoch 27/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4758 - mae: 0.5517 - val_loss: 0.4772 - val_mae: 0.5430 - learning_rate: 0.0050
# Epoch 28/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4788 - mae: 0.5644 - val_loss: 0.4659 - val_mae: 0.5351 - learning_rate: 0.0050
# Epoch 29/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4626 - mae: 0.5365 - val_loss: 0.4561 - val_mae: 0.5265 - learning_rate: 0.0050
# Epoch 30/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4358 - mae: 0.5279 - val_loss: 0.4451 - val_mae: 0.5246 - learning_rate: 0.0050
# Epoch 31/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4592 - mae: 0.5424 - val_loss: 0.4455 - val_mae: 0.5283 - learning_rate: 0.0050
# Epoch 32/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4130 - mae: 0.5086 - val_loss: 0.4369 - val_mae: 0.5225 - learning_rate: 0.0050
# Epoch 33/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4493 - mae: 0.5383 - val_loss: 0.4311 - val_mae: 0.5155 - learning_rate: 0.0050
# Epoch 34/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4226 - mae: 0.5208 - val_loss: 0.4283 - val_mae: 0.5193 - learning_rate: 0.0050
# Epoch 35/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4060 - mae: 0.5090 - val_loss: 0.4215 - val_mae: 0.5131 - learning_rate: 0.0050
# Epoch 36/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3811 - mae: 0.4944 - val_loss: 0.4182 - val_mae: 0.5143 - learning_rate: 0.0050
# Epoch 37/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4049 - mae: 0.5110 - val_loss: 0.4344 - val_mae: 0.5352 - learning_rate: 0.0050
# Epoch 38/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4011 - mae: 0.5018 - val_loss: 0.4108 - val_mae: 0.5099 - learning_rate: 0.0050
# Epoch 39/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3787 - mae: 0.4933 - val_loss: 0.4195 - val_mae: 0.5218 - learning_rate: 0.0050
# Epoch 40/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3907 - mae: 0.4944 - val_loss: 0.4136 - val_mae: 0.5174 - learning_rate: 0.0050
# Epoch 41/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3771 - mae: 0.4948 - val_loss: 0.4027 - val_mae: 0.5087 - learning_rate: 0.0050
# Epoch 42/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3944 - mae: 0.4952 - val_loss: 0.4108 - val_mae: 0.5078 - learning_rate: 0.0050
# Epoch 43/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4000 - mae: 0.5007 - val_loss: 0.4008 - val_mae: 0.5082 - learning_rate: 0.0050
# Epoch 44/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3700 - mae: 0.4929 - val_loss: 0.4292 - val_mae: 0.5355 - learning_rate: 0.0050
# Epoch 45/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4009 - mae: 0.5024 - val_loss: 0.4088 - val_mae: 0.5160 - learning_rate: 0.0050
# Epoch 46/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3760 - mae: 0.4905 - val_loss: 0.3884 - val_mae: 0.5001 - learning_rate: 0.0050
# Epoch 47/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3604 - mae: 0.4778 - val_loss: 0.3988 - val_mae: 0.5118 - learning_rate: 0.0050
# Epoch 48/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3847 - mae: 0.4919 - val_loss: 0.3939 - val_mae: 0.5044 - learning_rate: 0.0050
# Epoch 49/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3698 - mae: 0.4876 - val_loss: 0.3929 - val_mae: 0.5025 - learning_rate: 0.0050
# Epoch 50/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3527 - mae: 0.4698 - val_loss: 0.3935 - val_mae: 0.5058 - learning_rate: 0.0050
# Epoch 51/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3884 - mae: 0.4961 - val_loss: 0.3937 - val_mae: 0.5081 - learning_rate: 0.0050
# Epoch 52/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3651 - mae: 0.4820 - val_loss: 0.3915 - val_mae: 0.5056 - learning_rate: 0.0050
# Epoch 53/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3648 - mae: 0.4858 - val_loss: 0.3882 - val_mae: 0.5043 - learning_rate: 0.0050
# Epoch 54/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3331 - mae: 0.4601 - val_loss: 0.3909 - val_mae: 0.5044 - learning_rate: 0.0050
# Epoch 55/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3570 - mae: 0.4700 - val_loss: 0.3778 - val_mae: 0.4948 - learning_rate: 0.0050
# Epoch 56/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3618 - mae: 0.4780 - val_loss: 0.3907 - val_mae: 0.5032 - learning_rate: 0.0050
# Epoch 57/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3655 - mae: 0.4816 - val_loss: 0.3700 - val_mae: 0.4869 - learning_rate: 0.0050
# Epoch 58/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3443 - mae: 0.4646 - val_loss: 0.3588 - val_mae: 0.4818 - learning_rate: 0.0050
# Epoch 59/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3376 - mae: 0.4628 - val_loss: 0.3667 - val_mae: 0.4882 - learning_rate: 0.0050
# Epoch 60/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3527 - mae: 0.4668 - val_loss: 0.3581 - val_mae: 0.4819 - learning_rate: 0.0050
# Epoch 61/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3291 - mae: 0.4593 - val_loss: 0.3667 - val_mae: 0.4907 - learning_rate: 0.0050
# Epoch 62/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3308 - mae: 0.4544 - val_loss: 0.3697 - val_mae: 0.4891 - learning_rate: 0.0050
# Epoch 63/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3315 - mae: 0.4618 - val_loss: 0.3723 - val_mae: 0.4932 - learning_rate: 0.0050
# Epoch 64/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3360 - mae: 0.4615 - val_loss: 0.3647 - val_mae: 0.4847 - learning_rate: 0.0050
# Epoch 65/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3302 - mae: 0.4583 - val_loss: 0.3657 - val_mae: 0.4874 - learning_rate: 0.0050
# Epoch 66/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3725 - mae: 0.4824 - val_loss: 0.3604 - val_mae: 0.4717 - learning_rate: 0.0050
# Epoch 67/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3266 - mae: 0.4564 - val_loss: 0.3604 - val_mae: 0.4828 - learning_rate: 0.0050
# Epoch 68/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3438 - mae: 0.4671 - val_loss: 0.3654 - val_mae: 0.4836 - learning_rate: 0.0050
# Epoch 69/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3098 - mae: 0.4374 - val_loss: 0.3671 - val_mae: 0.4881 - learning_rate: 0.0050
# Epoch 70/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3077 - mae: 0.4387 - val_loss: 0.3629 - val_mae: 0.4832 - learning_rate: 0.0050
# Epoch 71/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3306 - mae: 0.4531 - val_loss: 0.3819 - val_mae: 0.5029 - learning_rate: 0.0050
# Epoch 72/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3174 - mae: 0.4459 - val_loss: 0.3688 - val_mae: 0.4875 - learning_rate: 0.0050
# Epoch 73/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3121 - mae: 0.4450 - val_loss: 0.3687 - val_mae: 0.4917 - learning_rate: 0.0050
# Epoch 74/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2999 - mae: 0.4353 - val_loss: 0.3688 - val_mae: 0.4883 - learning_rate: 0.0050
# Epoch 75/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3136 - mae: 0.4417 - val_loss: 0.3607 - val_mae: 0.4736 - learning_rate: 0.0050
# Epoch 76/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3145 - mae: 0.4483 - val_loss: 0.3673 - val_mae: 0.4825 - learning_rate: 0.0050
# Epoch 77/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3344 - mae: 0.4591 - val_loss: 0.3630 - val_mae: 0.4804 - learning_rate: 0.0050
# Epoch 78/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2967 - mae: 0.4327 - val_loss: 0.3801 - val_mae: 0.4898 - learning_rate: 0.0050
# Epoch 79/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3145 - mae: 0.4464 - val_loss: 0.3672 - val_mae: 0.4824 - learning_rate: 0.0050
# Epoch 80/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3265 - mae: 0.4518 - val_loss: 0.3804 - val_mae: 0.4999 - learning_rate: 0.0050
# Epoch 81/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2981 - mae: 0.4369 - val_loss: 0.3631 - val_mae: 0.4829 - learning_rate: 0.0025
# Epoch 82/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3018 - mae: 0.4345 - val_loss: 0.3627 - val_mae: 0.4832 - learning_rate: 0.0025
# Epoch 83/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3168 - mae: 0.4490 - val_loss: 0.3729 - val_mae: 0.4960 - learning_rate: 0.0025
# Epoch 84/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - mae: 0.4410 - val_loss: 0.3626 - val_mae: 0.4813 - learning_rate: 0.0025
# Epoch 85/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3076 - mae: 0.4382 - val_loss: 0.3645 - val_mae: 0.4841 - learning_rate: 0.0025
# Epoch 86/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3073 - mae: 0.4406 - val_loss: 0.3665 - val_mae: 0.4900 - learning_rate: 0.0025
# Epoch 87/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3107 - mae: 0.4407 - val_loss: 0.3689 - val_mae: 0.4911 - learning_rate: 0.0025
# Epoch 88/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3062 - mae: 0.4411 - val_loss: 0.3622 - val_mae: 0.4845 - learning_rate: 0.0025
# Epoch 89/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3052 - mae: 0.4388 - val_loss: 0.3613 - val_mae: 0.4822 - learning_rate: 0.0025
# Epoch 90/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3001 - mae: 0.4337 - val_loss: 0.3633 - val_mae: 0.4873 - learning_rate: 0.0025
# Epoch 91/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2896 - mae: 0.4287 - val_loss: 0.3647 - val_mae: 0.4883 - learning_rate: 0.0025
# Epoch 92/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3007 - mae: 0.4361 - val_loss: 0.3657 - val_mae: 0.4853 - learning_rate: 0.0025
# Epoch 93/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3009 - mae: 0.4372 - val_loss: 0.3622 - val_mae: 0.4851 - learning_rate: 0.0025
# Epoch 94/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3256 - mae: 0.4545 - val_loss: 0.3643 - val_mae: 0.4885 - learning_rate: 0.0025
# Epoch 95/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3041 - mae: 0.4321 - val_loss: 0.3702 - val_mae: 0.4928 - learning_rate: 0.0025
# Epoch 96/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3012 - mae: 0.4342 - val_loss: 0.3624 - val_mae: 0.4828 - learning_rate: 0.0025
# Epoch 97/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2737 - mae: 0.4111 - val_loss: 0.3660 - val_mae: 0.4896 - learning_rate: 0.0025
# Epoch 98/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2979 - mae: 0.4343 - val_loss: 0.3686 - val_mae: 0.4929 - learning_rate: 0.0025
# Epoch 99/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2987 - mae: 0.4355 - val_loss: 0.3598 - val_mae: 0.4825 - learning_rate: 0.0025
# Epoch 100/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3011 - mae: 0.4334 - val_loss: 0.3643 - val_mae: 0.4897 - learning_rate: 0.0025
# Epoch 101/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2905 - mae: 0.4259 - val_loss: 0.3579 - val_mae: 0.4825 - learning_rate: 0.0012
# Epoch 102/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.
3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2730 - mae: 0.4094 - val_loss: 0.3432 - val_mae: 0.4716 - learning_rate: 6.2500e-04
# Epoch 205/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2850 - mae: 0.4201 - val_loss: 0.3437 - val_mae: 0.4720 - learning_rate: 6.2500e-04
# Epoch 206/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2680 - mae: 0.4111 - val_loss: 0.3445 - val_mae: 0.4728 - learning_rate: 6.2500e-04
# Epoch 207/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2706 - mae: 0.4131 - val_loss: 0.3433 - val_mae: 0.4712 - learning_rate: 6.2500e-04
# Epoch 208/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2644 - mae: 0.4091 - val_loss: 0.3449 - val_mae: 0.4733 - learning_rate: 6.2500e-04
# Epoch 209/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2648 - mae: 0.4038 - val_loss: 0.3439 - val_mae: 0.4723 - learning_rate: 6.2500e-04
# Epoch 210/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2817 - mae: 0.4193 - val_loss: 0.3442 - val_mae: 0.4725 - learning_rate: 6.2500e-04
# Epoch 211/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2684 - mae: 0.4090 - val_loss: 0.3434 - val_mae: 0.4717 - learning_rate: 6.2500e-04
# Epoch 212/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2754 - mae: 0.4226 - val_loss: 0.3425 - val_mae: 0.4701 - learning_rate: 6.2500e-04
# Epoch 213/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2557 - mae: 0.4018 - val_loss: 0.3464 - val_mae: 0.4748 - learning_rate: 6.2500e-04
# Epoch 214/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2787 - mae: 0.4214 - val_loss: 0.3429 - val_mae: 0.4709 - learning_rate: 6.2500e-04
# Epoch 215/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2589 - mae: 0.4043 - val_loss: 0.3431 - val_mae: 0.4713 - learning_rate: 6.2500e-04
# Epoch 216/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2662 - mae: 0.4062 - val_loss: 0.3455 - val_mae: 0.4734 - learning_rate: 6.2500e-04
# Epoch 217/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2783 - mae: 0.4167 - val_loss: 0.3432 - val_mae: 0.4706 - learning_rate: 6.2500e-04
# Epoch 218/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2669 - mae: 0.4091 - val_loss: 0.3445 - val_mae: 0.4723 - learning_rate: 6.2500e-04
# Epoch 219/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2683 - mae: 0.4077 - val_loss: 0.3426 - val_mae: 0.4708 - learning_rate: 6.2500e-04
# Epoch 220/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2728 - mae: 0.4187 - val_loss: 0.3442 - val_mae: 0.4726 - learning_rate: 6.2500e-04
# Epoch 221/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2721 - mae: 0.4140 - val_loss: 0.3429 - val_mae: 0.4711 - learning_rate: 6.2500e-04
# Epoch 222/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2697 - mae: 0.4114 - val_loss: 0.3446 - val_mae: 0.4729 - learning_rate: 6.2500e-04
# Epoch 223/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2727 - mae: 0.4156 - val_loss: 0.3426 - val_mae: 0.4707 - learning_rate: 6.2500e-04
# Epoch 224/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2705 - mae: 0.4130 - val_loss: 0.3442 - val_mae: 0.4727 - learning_rate: 3.1250e-04
# Epoch 225/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2762 - mae: 0.4173 - val_loss: 0.3424 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 226/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2698 - mae: 0.4087 - val_loss: 0.3429 - val_mae: 0.4714 - learning_rate: 3.1250e-04
# Epoch 227/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2890 - mae: 0.4288 - val_loss: 0.3438 - val_mae: 0.4720 - learning_rate: 3.1250e-04
# Epoch 228/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2712 - mae: 0.4126 - val_loss: 0.3440 - val_mae: 0.4721 - learning_rate: 3.1250e-04
# Epoch 229/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2899 - mae: 0.4250 - val_loss: 0.3427 - val_mae: 0.4708 - learning_rate: 3.1250e-04
# Epoch 230/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2486 - mae: 0.3977 - val_loss: 0.3425 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 231/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2615 - mae: 0.4069 - val_loss: 0.3430 - val_mae: 0.4715 - learning_rate: 3.1250e-04
# Epoch 232/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2778 - mae: 0.4217 - val_loss: 0.3428 - val_mae: 0.4710 - learning_rate: 3.1250e-04
# Epoch 233/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2773 - mae: 0.4172 - val_loss: 0.3425 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 234/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2801 - mae: 0.4206 - val_loss: 0.3431 - val_mae: 0.4716 - learning_rate: 3.1250e-04
# Epoch 235/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2667 - mae: 0.4106 - val_loss: 0.3425 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 236/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2722 - mae: 0.4202 - val_loss: 0.3419 - val_mae: 0.4701 - learning_rate: 3.1250e-04
# Epoch 237/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2705 - mae: 0.4109 - val_loss: 0.3428 - val_mae: 0.4711 - learning_rate: 3.1250e-04
# Epoch 238/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2823 - mae: 0.4151 - val_loss: 0.3427 - val_mae: 0.4711 - learning_rate: 3.1250e-04
# Epoch 239/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2784 - mae: 0.4189 - val_loss: 0.3425 - val_mae: 0.4710 - learning_rate: 3.1250e-04
# Epoch 240/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2766 - mae: 0.4204 - val_loss: 0.3423 - val_mae: 0.4705 - learning_rate: 3.1250e-04
# Epoch 241/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2744 - mae: 0.4155 - val_loss: 0.3433 - val_mae: 0.4718 - learning_rate: 3.1250e-04
# Epoch 242/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2532 - mae: 0.4059 - val_loss: 0.3427 - val_mae: 0.4711 - learning_rate: 3.1250e-04
# Epoch 243/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2443 - mae: 0.3969 - val_loss: 0.3431 - val_mae: 0.4715 - learning_rate: 3.1250e-04
# Epoch 244/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2769 - mae: 0.4139 - val_loss: 0.3418 - val_mae: 0.4701 - learning_rate: 3.1250e-04
# Epoch 245/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3037 - mae: 0.4388 - val_loss: 0.3425 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 246/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2942 - mae: 0.4301 - val_loss: 0.3422 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 247/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2681 - mae: 0.4118 - val_loss: 0.3421 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 248/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2631 - mae: 0.3988 - val_loss: 0.3435 - val_mae: 0.4721 - learning_rate: 3.1250e-04
# Epoch 249/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2849 - mae: 0.4230 - val_loss: 0.3420 - val_mae: 0.4703 - learning_rate: 3.1250e-04
# Epoch 250/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2690 - mae: 0.4109 - val_loss: 0.3428 - val_mae: 0.4715 - learning_rate: 3.1250e-04
# Epoch 251/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2678 - mae: 0.4095 - val_loss: 0.3414 - val_mae: 0.4700 - learning_rate: 3.1250e-04
# Epoch 252/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2753 - mae: 0.4135 - val_loss: 0.3427 - val_mae: 0.4715 - learning_rate: 3.1250e-04
# Epoch 253/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2896 - mae: 0.4237 - val_loss: 0.3424 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 254/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2599 - mae: 0.4078 - val_loss: 0.3424 - val_mae: 0.4708 - learning_rate: 3.1250e-04
# Epoch 255/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2773 - mae: 0.4207 - val_loss: 0.3430 - val_mae: 0.4715 - learning_rate: 3.1250e-04
# Epoch 256/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2589 - mae: 0.4029 - val_loss: 0.3417 - val_mae: 0.4701 - learning_rate: 3.1250e-04
# Epoch 257/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2670 - mae: 0.4175 - val_loss: 0.3424 - val_mae: 0.4712 - learning_rate: 3.1250e-04
# Epoch 258/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2758 - mae: 0.4145 - val_loss: 0.3422 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 259/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2909 - mae: 0.4252 - val_loss: 0.3418 - val_mae: 0.4705 - learning_rate: 3.1250e-04
# Epoch 260/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2898 - mae: 0.4196 - val_loss: 0.3416 - val_mae: 0.4704 - learning_rate: 3.1250e-04
# Epoch 261/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2512 - mae: 0.3998 - val_loss: 0.3426 - val_mae: 0.4717 - learning_rate: 3.1250e-04
# Epoch 262/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2732 - mae: 0.4157 - val_loss: 0.3419 - val_mae: 0.4707 - learning_rate: 3.1250e-04
# Epoch 263/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2642 - mae: 0.4126 - val_loss: 0.3428 - val_mae: 0.4716 - learning_rate: 3.1250e-04
# Epoch 264/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2800 - mae: 0.4200 - val_loss: 0.3419 - val_mae: 0.4707 - learning_rate: 3.1250e-04
# Epoch 265/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2552 - mae: 0.3998 - val_loss: 0.3409 - val_mae: 0.4691 - learning_rate: 3.1250e-04
# Epoch 266/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2645 - mae: 0.4097 - val_loss: 0.3421 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 267/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2751 - mae: 0.4201 - val_loss: 0.3421 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 268/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2659 - mae: 0.4072 - val_loss: 0.3434 - val_mae: 0.4718 - learning_rate: 3.1250e-04
# Epoch 269/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2793 - mae: 0.4219 - val_loss: 0.3420 - val_mae: 0.4710 - learning_rate: 3.1250e-04
# Epoch 270/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2688 - mae: 0.4091 - val_loss: 0.3421 - val_mae: 0.4714 - learning_rate: 3.1250e-04
# Epoch 271/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2680 - mae: 0.4059 - val_loss: 0.3409 - val_mae: 0.4698 - learning_rate: 3.1250e-04
# Epoch 272/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2537 - mae: 0.4011 - val_loss: 0.3419 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 273/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2795 - mae: 0.4167 - val_loss: 0.3417 - val_mae: 0.4703 - learning_rate: 3.1250e-04
# Epoch 274/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2800 - mae: 0.4196 - val_loss: 0.3417 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 275/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2613 - mae: 0.4040 - val_loss: 0.3421 - val_mae: 0.4711 - learning_rate: 3.1250e-04
# Epoch 276/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2523 - mae: 0.3953 - val_loss: 0.3413 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 277/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2878 - mae: 0.4248 - val_loss: 0.3421 - val_mae: 0.4711 - learning_rate: 3.1250e-04
# Epoch 278/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2457 - mae: 0.3944 - val_loss: 0.3421 - val_mae: 0.4710 - learning_rate: 3.1250e-04
# Epoch 279/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2773 - mae: 0.4251 - val_loss: 0.3411 - val_mae: 0.4700 - learning_rate: 3.1250e-04
# Epoch 280/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2620 - mae: 0.4074 - val_loss: 0.3415 - val_mae: 0.4706 - learning_rate: 3.1250e-04
# Epoch 281/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2684 - mae: 0.4114 - val_loss: 0.3405 - val_mae: 0.4696 - learning_rate: 3.1250e-04
# Epoch 282/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2510 - mae: 0.3972 - val_loss: 0.3415 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 283/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2676 - mae: 0.4166 - val_loss: 0.3413 - val_mae: 0.4705 - learning_rate: 3.1250e-04
# Epoch 284/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2825 - mae: 0.4299 - val_loss: 0.3405 - val_mae: 0.4695 - learning_rate: 3.1250e-04
# Epoch 285/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2540 - mae: 0.4025 - val_loss: 0.3412 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 286/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2557 - mae: 0.4036 - val_loss: 0.3412 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 287/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2729 - mae: 0.4177 - val_loss: 0.3409 - val_mae: 0.4697 - learning_rate: 3.1250e-04
# Epoch 288/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2681 - mae: 0.4107 - val_loss: 0.3410 - val_mae: 0.4703 - learning_rate: 3.1250e-04
# Epoch 289/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2606 - mae: 0.4066 - val_loss: 0.3411 - val_mae: 0.4704 - learning_rate: 3.1250e-04
# Epoch 290/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2867 - mae: 0.4266 - val_loss: 0.3413 - val_mae: 0.4703 - learning_rate: 3.1250e-04
# Epoch 291/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2621 - mae: 0.4084 - val_loss: 0.3408 - val_mae: 0.4698 - learning_rate: 3.1250e-04
# Epoch 292/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2718 - mae: 0.4171 - val_loss: 0.3409 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 293/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2503 - mae: 0.3984 - val_loss: 0.3408 - val_mae: 0.4701 - learning_rate: 3.1250e-04
# Epoch 294/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2784 - mae: 0.4192 - val_loss: 0.3418 - val_mae: 0.4708 - learning_rate: 3.1250e-04
# Epoch 295/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2729 - mae: 0.4151 - val_loss: 0.3414 - val_mae: 0.4705 - learning_rate: 3.1250e-04
# Epoch 296/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2639 - mae: 0.4053 - val_loss: 0.3408 - val_mae: 0.4701 - learning_rate: 3.1250e-04
# Epoch 297/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2820 - mae: 0.4231 - val_loss: 0.3406 - val_mae: 0.4697 - learning_rate: 3.1250e-04
# Epoch 298/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2735 - mae: 0.4162 - val_loss: 0.3404 - val_mae: 0.4696 - learning_rate: 3.1250e-04
# Epoch 299/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2549 - mae: 0.4023 - val_loss: 0.3402 - val_mae: 0.4693 - learning_rate: 3.1250e-04
# Epoch 300/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2715 - mae: 0.4133 - val_loss: 0.3417 - val_mae: 0.4709 - learning_rate: 3.1250e-04
# Epoch 301/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2746 - mae: 0.4175 - val_loss: 0.3403 - val_mae: 0.4694 - learning_rate: 3.1250e-04
# Epoch 302/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2855 - mae: 0.4270 - val_loss: 0.3410 - val_mae: 0.4701 - learning_rate: 3.1250e-04
# Epoch 303/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2610 - mae: 0.4133 - val_loss: 0.3412 - val_mae: 0.4700 - learning_rate: 3.1250e-04
# Epoch 304/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2725 - mae: 0.4164 - val_loss: 0.3405 - val_mae: 0.4695 - learning_rate: 3.1250e-04
# Epoch 305/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2782 - mae: 0.4173 - val_loss: 0.3401 - val_mae: 0.4689 - learning_rate: 3.1250e-04
# Epoch 306/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2709 - mae: 0.4083 - val_loss: 0.3410 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 307/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2356 - mae: 0.3860 - val_loss: 0.3413 - val_mae: 0.4705 - learning_rate: 3.1250e-04
# Epoch 308/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2635 - mae: 0.4095 - val_loss: 0.3405 - val_mae: 0.4698 - learning_rate: 3.1250e-04
# Epoch 309/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2646 - mae: 0.4108 - val_loss: 0.3402 - val_mae: 0.4693 - learning_rate: 3.1250e-04
# Epoch 310/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2671 - mae: 0.4157 - val_loss: 0.3408 - val_mae: 0.4702 - learning_rate: 3.1250e-04
# Epoch 311/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2866 - mae: 0.4202 - val_loss: 0.3403 - val_mae: 0.4694 - learning_rate: 3.1250e-04
# Epoch 312/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2726 - mae: 0.4106 - val_loss: 0.3417 - val_mae: 0.4713 - learning_rate: 3.1250e-04
# Epoch 313/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2689 - mae: 0.4109 - val_loss: 0.3395 - val_mae: 0.4685 - learning_rate: 3.1250e-04
# Epoch 314/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2670 - mae: 0.4043 - val_loss: 0.3409 - val_mae: 0.4699 - learning_rate: 3.1250e-04
# Epoch 315/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2994 - mae: 0.4319 - val_loss: 0.3393 - val_mae: 0.4680 - learning_rate: 3.1250e-04
# Epoch 316/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2698 - mae: 0.4096 - val_loss: 0.3416 - val_mae: 0.4704 - learning_rate: 3.1250e-04
# Epoch 317/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2644 - mae: 0.4014 - val_loss: 0.3413 - val_mae: 0.4708 - learning_rate: 3.1250e-04
# Epoch 318/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2717 - mae: 0.4097 - val_loss: 0.3411 - val_mae: 0.4705 - learning_rate: 3.1250e-04
# Epoch 319/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2587 - mae: 0.4070 - val_loss: 0.3404 - val_mae: 0.4700 - learning_rate: 3.1250e-04
# Epoch 320/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2610 - mae: 0.4074 - val_loss: 0.3398 - val_mae: 0.4691 - learning_rate: 3.1250e-04
# Epoch 321/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2789 - mae: 0.4184 - val_loss: 0.3392 - val_mae: 0.4682 - learning_rate: 3.1250e-04
# Epoch 322/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2847 - mae: 0.4217 - val_loss: 0.3400 - val_mae: 0.4692 - learning_rate: 3.1250e-04
# Epoch 323/3000
# ...
# Epoch 629/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2590 - mae: 0.4067 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 630/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2550 - mae: 0.4010 - val_loss: 0.3354 - val_mae: 0.4659 - learning_rate: 1.0000e-04
# Epoch 631/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2520 - mae: 0.3993 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 632/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2625 - mae: 0.4047 - val_loss: 0.3358 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 633/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2502 - mae: 0.3969 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 634/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2621 - mae: 0.4112 - val_loss: 0.3358 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 635/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2540 - mae: 0.4026 - val_loss: 0.3358 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 636/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2720 - mae: 0.4143 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 637/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2758 - mae: 0.4137 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 638/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2734 - mae: 0.4120 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 639/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2789 - mae: 0.4231 - val_loss: 0.3356 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 640/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2543 - mae: 0.4009 - val_loss: 0.3358 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 641/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2692 - mae: 0.4090 - val_loss: 0.3357 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 642/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2614 - mae: 0.4058 - val_loss: 0.3361 - val_mae: 0.4669 - learning_rate: 1.0000e-04
# Epoch 643/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2658 - mae: 0.4084 - val_loss: 0.3355 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 644/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2657 - mae: 0.4073 - val_loss: 0.3353 - val_mae: 0.4659 - learning_rate: 1.0000e-04
# Epoch 645/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2516 - mae: 0.3984 - val_loss: 0.3351 - val_mae: 0.4654 - learning_rate: 1.0000e-04
# Epoch 646/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2623 - mae: 0.4080 - val_loss: 0.3355 - val_mae: 0.4659 - learning_rate: 1.0000e-04
# Epoch 647/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2692 - mae: 0.4118 - val_loss: 0.3359 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 648/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2595 - mae: 0.3992 - val_loss: 0.3356 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 649/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2646 - mae: 0.4104 - val_loss: 0.3354 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 650/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2706 - mae: 0.4133 - val_loss: 0.3357 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 651/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2633 - mae: 0.4103 - val_loss: 0.3357 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 652/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2549 - mae: 0.3960 - val_loss: 0.3359 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 653/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2613 - mae: 0.4029 - val_loss: 0.3357 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 654/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2854 - mae: 0.4207 - val_loss: 0.3358 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 655/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2527 - mae: 0.3972 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 656/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2565 - mae: 0.3989 - val_loss: 0.3362 - val_mae: 0.4669 - learning_rate: 1.0000e-04
# Epoch 657/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2717 - mae: 0.4125 - val_loss: 0.3356 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 658/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2639 - mae: 0.4038 - val_loss: 0.3357 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 659/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2609 - mae: 0.4119 - val_loss: 0.3360 - val_mae: 0.4666 - learning_rate: 1.0000e-04
# Epoch 660/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2648 - mae: 0.4094 - val_loss: 0.3354 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 661/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2634 - mae: 0.4099 - val_loss: 0.3356 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 662/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2723 - mae: 0.4149 - val_loss: 0.3357 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 663/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2629 - mae: 0.4089 - val_loss: 0.3355 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 664/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2587 - mae: 0.4042 - val_loss: 0.3360 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 665/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2763 - mae: 0.4174 - val_loss: 0.3355 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 666/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2626 - mae: 0.4082 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 667/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2447 - mae: 0.3961 - val_loss: 0.3360 - val_mae: 0.4666 - learning_rate: 1.0000e-04
# Epoch 668/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2536 - mae: 0.4015 - val_loss: 0.3359 - val_mae: 0.4666 - learning_rate: 1.0000e-04
# Epoch 669/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2907 - mae: 0.4304 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 670/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2714 - mae: 0.4122 - val_loss: 0.3356 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 671/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2741 - mae: 0.4198 - val_loss: 0.3358 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 672/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2682 - mae: 0.4110 - val_loss: 0.3357 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 673/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2576 - mae: 0.4074 - val_loss: 0.3358 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 674/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2550 - mae: 0.4019 - val_loss: 0.3359 - val_mae: 0.4666 - learning_rate: 1.0000e-04
# Epoch 675/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2634 - mae: 0.4057 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 676/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2731 - mae: 0.4165 - val_loss: 0.3358 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 677/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2557 - mae: 0.4042 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 678/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2700 - mae: 0.4152 - val_loss: 0.3356 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 679/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2672 - mae: 0.4075 - val_loss: 0.3353 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 680/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2491 - mae: 0.3949 - val_loss: 0.3358 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 681/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2554 - mae: 0.4008 - val_loss: 0.3356 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 682/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2651 - mae: 0.4119 - val_loss: 0.3359 - val_mae: 0.4666 - learning_rate: 1.0000e-04
# Epoch 683/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2449 - mae: 0.3886 - val_loss: 0.3355 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 684/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2645 - mae: 0.4084 - val_loss: 0.3358 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 685/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2793 - mae: 0.4158 - val_loss: 0.3350 - val_mae: 0.4654 - learning_rate: 1.0000e-04
# Epoch 686/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2591 - mae: 0.4033 - val_loss: 0.3356 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 687/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2487 - mae: 0.3931 - val_loss: 0.3359 - val_mae: 0.4667 - learning_rate: 1.0000e-04
# Epoch 688/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2666 - mae: 0.4090 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 689/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2466 - mae: 0.3954 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 690/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2582 - mae: 0.4026 - val_loss: 0.3356 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 691/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2464 - mae: 0.3932 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 692/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2680 - mae: 0.4131 - val_loss: 0.3356 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 693/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2579 - mae: 0.4000 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 694/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2639 - mae: 0.4089 - val_loss: 0.3353 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 695/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2700 - mae: 0.4201 - val_loss: 0.3353 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 696/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2870 - mae: 0.4225 - val_loss: 0.3356 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 697/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2755 - mae: 0.4175 - val_loss: 0.3356 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 698/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2699 - mae: 0.4136 - val_loss: 0.3353 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 699/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2675 - mae: 0.4040 - val_loss: 0.3356 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 700/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2584 - mae: 0.4030 - val_loss: 0.3356 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 701/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2634 - mae: 0.4135 - val_loss: 0.3352 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 702/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2579 - mae: 0.4061 - val_loss: 0.3354 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 703/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2605 - mae: 0.4060 - val_loss: 0.3352 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 704/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2504 - mae: 0.3963 - val_loss: 0.3358 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 705/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2771 - mae: 0.4157 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 706/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2551 - mae: 0.4029 - val_loss: 0.3359 - val_mae: 0.4667 - learning_rate: 1.0000e-04
# Epoch 707/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2608 - mae: 0.4033 - val_loss: 0.3351 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 708/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2689 - mae: 0.4107 - val_loss: 0.3351 - val_mae: 0.4657 - learning_rate: 1.0000e-04
# Epoch 709/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2437 - mae: 0.3944 - val_loss: 0.3354 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 710/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2489 - mae: 0.3942 - val_loss: 0.3354 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 711/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2619 - mae: 0.4062 - val_loss: 0.3357 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 712/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2630 - mae: 0.4079 - val_loss: 0.3352 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 713/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2671 - mae: 0.4097 - val_loss: 0.3358 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 714/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2785 - mae: 0.4184 - val_loss: 0.3356 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 715/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2784 - mae: 0.4141 - val_loss: 0.3352 - val_mae: 0.4656 - learning_rate: 1.0000e-04
# Epoch 716/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2533 - mae: 0.4022 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 717/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2546 - mae: 0.4011 - val_loss: 0.3357 - val_mae: 0.4665 - learning_rate: 1.0000e-04
# Epoch 718/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2706 - mae: 0.4150 - val_loss: 0.3355 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 719/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2674 - mae: 0.4079 - val_loss: 0.3352 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 720/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2675 - mae: 0.4141 - val_loss: 0.3354 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 721/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2593 - mae: 0.4047 - val_loss: 0.3355 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 722/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2581 - mae: 0.4093 - val_loss: 0.3356 - val_mae: 0.4664 - learning_rate: 1.0000e-04
# Epoch 723/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2622 - mae: 0.4038 - val_loss: 0.3354 - val_mae: 0.4660 - learning_rate: 1.0000e-04
# Epoch 724/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2546 - mae: 0.4037 - val_loss: 0.3355 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 725/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2672 - mae: 0.4112 - val_loss: 0.3356 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 726/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2554 - mae: 0.3958 - val_loss: 0.3354 - val_mae: 0.4659 - learning_rate: 1.0000e-04
# Epoch 727/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2767 - mae: 0.4186 - val_loss: 0.3353 - val_mae: 0.4659 - learning_rate: 1.0000e-04
# Epoch 728/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2580 - mae: 0.4009 - val_loss: 0.3356 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 729/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2512 - mae: 0.4006 - val_loss: 0.3353 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 730/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2491 - mae: 0.3997 - val_loss: 0.3353 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 731/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2527 - mae: 0.3985 - val_loss: 0.3357 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Epoch 732/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2549 - mae: 0.4095 - val_loss: 0.3357 - val_mae: 0.4662 - learning_rate: 1.0000e-04
# Epoch 733/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2800 - mae: 0.4190 - val_loss: 0.3355 - val_mae: 0.4661 - learning_rate: 1.0000e-04
# Epoch 734/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2516 - mae: 0.3978 - val_loss: 0.3352 - val_mae: 0.4658 - learning_rate: 1.0000e-04
# Epoch 735/3000
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2727 - mae: 0.4138 - val_loss: 0.3356 - val_mae: 0.4663 - learning_rate: 1.0000e-04
# Training completed in 68.49 seconds

# %% [markdown]
# ## Model Evaluation and Visualization
#
# Now let's evaluate our TensorFlow model created with the Functional API and visualize the training progress and predictions.

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot MAE metric
plt.figure(figsize=(10, 6))
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.title('Training and Validation MAE')
plt.legend()
plt.grid(True)
plt.show()

# Evaluate on test set
test_results = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss (MSE): {test_results[0]:.6f}")
print(f"Test MAE: {test_results[1]:.6f}")

# Get predictions
y_pred_test = model.predict(X_test)

# Visualize predictions vs actual values
plt.figure(figsize=(10, 6))
plt.scatter(y_test.numpy(), y_pred_test, alpha=0.5)
plt.plot([-5, 5], [-5, 5], 'r--')  # Perfect prediction line
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predictions vs Actual Values')
plt.grid(True)
plt.show()

# Create a 4D visualization (3D plot with color as the 4th dimension)
def visualize_4d(X, y_true, y_pred, title):
    # Convert tensors to numpy
    X_np = X.numpy()
    y_true_np = y_true.numpy().flatten()
    y_pred_np = y_pred.flatten()

    # Create a 3D scatter plot with color as the 4th dimension
    fig = plt.figure(figsize=(12, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Calculate prediction error for coloring
    error = y_true_np - y_pred_np

    # Create the scatter plot
    scatter = ax.scatter(X_np[:, 0], X_np[:, 1], X_np[:, 2],
                          c=error,  # Use error for coloring
                          cmap=cm.coolwarm,
                          marker='o',
                          alpha=0.7,
                          s=30)

    # Add a color bar
    cbar = plt.colorbar(scatter)
    cbar.set_label('Prediction Error')

    # Set labels and title
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('X3')
    ax.set_title(title)

    # Show the plot
    plt.show()

# Generate sample data points for visualization
X_vis, y_vis = generate_data(200)

# Get predictions for visualization
y_vis_pred = model.predict(X_vis)

# Create 4D visualization
visualize_4d(X_vis, y_vis, y_vis_pred, '4D Visualization of Model Predictions vs Actual Values')
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3051 - mae: 0.4393
# Test Loss (MSE): 0.335025
# Test MAE: 0.465420
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# Alternative visualization with 2D slices
def plot_2d_slices(X_range=2.0, grid_points=20):
    # Create a grid of points for visualization
    x1 = np.linspace(-X_range, X_range, grid_points)
    x2 = np.linspace(-X_range, X_range, grid_points)
    x3_values = [-1.5, 0, 1.5]  # Three fixed values for x3

    fig, axes = plt.subplots(1, len(x3_values), figsize=(18, 5))

    for i, x3 in enumerate(x3_values):
        # Create meshgrid for x1 and x2
        X1, X2 = np.meshgrid(x1, x2)

        # Create input data with fixed x3
        X_input_np = np.zeros((grid_points*grid_points, 3))
        X_input_np[:, 0] = X1.flatten()
        X_input_np[:, 1] = X2.flatten()
        X_input_np[:, 2] = x3

        # Convert to tensor
        X_input = tf.convert_to_tensor(X_input_np, dtype=tf.float32)

        # Get true values and predictions
        y_true = true_function(X_input).numpy().reshape(grid_points, grid_points)
        y_pred = model.predict(X_input).reshape(grid_points, grid_points)

        # Plot the true function
        im1 = axes[i].contourf(X1, X2, y_true, cmap='viridis', levels=20)
        axes[i].set_title(f'True Function (x3={x3})')
        axes[i].set_xlabel('X1')
        axes[i].set_ylabel('X2')

        # Add a colorbar
        plt.colorbar(im1, ax=axes[i])

    plt.tight_layout()
    plt.show()

    # Now plot the predicted function
    fig, axes = plt.subplots(1, len(x3_values), figsize=(18, 5))

    for i, x3 in enumerate(x3_values):
        # Create meshgrid for x1 and x2
        X1, X2 = np.meshgrid(x1, x2)

        # Create input data with fixed x3
        X_input_np = np.zeros((grid_points*grid_points, 3))
        X_input_np[:, 0] = X1.flatten()
        X_input_np[:, 1] = X2.flatten()
        X_input_np[:, 2] = x3

        # Convert to tensor
        X_input = tf.convert_to_tensor(X_input_np, dtype=tf.float32)

        # Get true values and predictions
        y_true = true_function(X_input).numpy().reshape(grid_points, grid_points)
        y_pred = model.predict(X_input).reshape(grid_points, grid_points)

        # Plot the predicted function
        im2 = axes[i].contourf(X1, X2, y_pred, cmap='viridis', levels=20)
        axes[i].set_title(f'Neural Network Prediction (x3={x3})')
        axes[i].set_xlabel('X1')
        axes[i].set_ylabel('X2')

        # Add a colorbar
        plt.colorbar(im2, ax=axes[i])

    plt.tight_layout()
    plt.show()

# Generate and plot 2D slices
plot_2d_slices(X_range=2.0, grid_points=20)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## Summary
#
# In this notebook, we've implemented a 3-layer neural network using TensorFlow's Functional API. Key features of this implementation:
#
# 1. Used the Functional API for model creation, allowing for more complex architectures
# 2. Leveraged TensorFlow's built-in training features with `model.fit()`
# 3. Used callbacks for early stopping and learning rate adjustment
# 4. Monitored both MSE (loss) and MAE (metric) during training
# 5. Visualized the model's predictions with various techniques
#
# This implementation offers the highest level of abstraction while still maintaining flexibility. The Functional API allows for more complex model architectures compared to the Sequential API, which could be beneficial for more advanced use cases.
#
# The model successfully learned to approximate our non-linear 3-variable function, with performance comparable to previous implementations. The visualizations show how well the model has learned the underlying patterns in the data.
#
# This completes all the required implementations for the assignment:
# 1. NumPy implementation from scratch
# 2. PyTorch implementation from scratch
# 3. PyTorch implementation with built-in functionality
# 4. PyTorch Lightning implementation
# 5. TensorFlow low-level implementation with einsum
# 6. TensorFlow implementation with built-in layers
# 7. TensorFlow implementation with the Functional API
#
# Each implementation has its advantages and use cases, but they all accomplish the same task of learning the non-linear relationship in our synthetic dataset.
